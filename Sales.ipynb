# %% [markdown]
# # Loading Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_excel('Sales.xlsx',sheet_name='Sales')
data
# Out:
#        CustID  AgentBonus   Age  CustTenure              Channel  \
# 0     7000000        4409  22.0         4.0                Agent
# 1     7000001        2214  11.0         2.0  Third Party Partner
# 2     7000002        4273  26.0         4.0                Agent
# 3     7000003        1791  11.0         NaN  Third Party Partner
# 4     7000004        2955   6.0         NaN                Agent
# ...       ...         ...   ...         ...                  ...
# 4515  7004515        3953   4.0         8.0                Agent
# 4516  7004516        2939   9.0         9.0                Agent
# 4517  7004517        3792  23.0        23.0                Agent
# 4518  7004518        4816  10.0        10.0               Online
# 4519  7004519        4764  14.0        10.0                Agent
#
#           Occupation  EducationField   Gender  ExistingProdType  \
# 0           Salaried        Graduate   Female                 3
# ...

# %%
data.Channel.unique()
# Out:
# array(['Agent', 'Third Party Partner', 'Online'], dtype=object)

# %% [markdown]
# # Data Exploration

# %%
print('\nInformation of the data...... \n')
print(data.info())
print('\nColumn names of the dataset...... \n', data.columns)


print('\nBelow is the first few lines of the dataset......\n', data.head(10))
print('\nBelow is the statistics of the dataset......\n',data.describe())
# Out:
# Information of the data......
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4520 entries, 0 to 4519
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustID                4520 non-null   int64
#  1   AgentBonus            4520 non-null   int64
#  2   Age                   4251 non-null   float64
#  3   CustTenure            4294 non-null   float64
#  4   Channel               4520 non-null   object
#  5   Occupation            4520 non-null   object
#  6   EducationField        4520 non-null   object
#  7   Gender                4520 non-null   object
#  8   ExistingProdType      4520 non-null   int64
#  9   Designation           4520 non-null   object
#  10  NumberOfPolicy        4475 non-null   float64
#  11  MaritalStatus         4520 non-null   object
#  12  MonthlyIncome         4284 non-null   float64
#  13  Complaint             4520 non-null   int64
# ...

# %%
data.columns
# Out:
# Index(['CustID', 'AgentBonus', 'Age', 'CustTenure', 'Channel', 'Occupation',
#        'EducationField', 'Gender', 'ExistingProdType', 'Designation',
#        'NumberOfPolicy', 'MaritalStatus', 'MonthlyIncome', 'Complaint',
#        'ExistingPolicyTenure', 'SumAssured', 'Zone', 'PaymentMethod',
#        'LastMonthCalls', 'CustCareScore'],
#       dtype='object')

# %%
data.dtypes
# Out:
# CustID                    int64
# AgentBonus                int64
# Age                     float64
# CustTenure              float64
# Channel                  object
# Occupation               object
# EducationField           object
# Gender                   object
# ExistingProdType          int64
# Designation              object
# NumberOfPolicy          float64
# MaritalStatus            object
# MonthlyIncome           float64
# Complaint                 int64
# ExistingPolicyTenure    float64
# SumAssured              float64
# Zone                     object
# PaymentMethod            object
# LastMonthCalls            int64
# CustCareScore           float64
# dtype: object

# %% [markdown]
# ## Scatter plot

# %%
# use scatter_matrix of pandas.plotting
# https://www.geeksforgeeks.org/pair-plots-using-scatter-matrix-in-pandas/
from pandas.plotting import scatter_matrix
scatter_matrix(data[['CustID', 'AgentBonus', 'Age', 'CustTenure', 'ExistingProdType',
       'NumberOfPolicy', 'MonthlyIncome', 'Complaint',
       'ExistingPolicyTenure', 'CustCareScore']], figsize=(16, 12))
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Calculate percentage counts of each classification type
classification_counts = data['Channel'].value_counts(normalize=True) * 100

# Plot the bar graph with percentage counts
plt.figure(figsize=(12, 6))
classification_counts.plot(kind='bar')
plt.title('Percentage Count of Each Channel')
plt.xlabel('Channel')
plt.ylabel('Percentage (%)')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
print(data.describe())  # it gives you the data of all ranges of boxplot
data.boxplot(figsize=(16, 8))
plt.title("Box Plot")
plt.xlabel("Column Names")
plt.ylabel("Outliers value")
plt.show()
# Out:
#              CustID   AgentBonus          Age   CustTenure  ExistingProdType  \
# count  4.520000e+03  4520.000000  4251.000000  4294.000000       4520.000000
# mean   7.002260e+06  4077.838274    14.494707    14.469027          3.688938
# std    1.304956e+03  1403.321711     9.037629     8.963671          1.015769
# min    7.000000e+06  1605.000000     2.000000     2.000000          1.000000
# 25%    7.001130e+06  3027.750000     7.000000     7.000000          3.000000
# 50%    7.002260e+06  3911.500000    13.000000    13.000000          4.000000
# 75%    7.003389e+06  4867.250000    20.000000    20.000000          4.000000
# max    7.004519e+06  9608.000000    58.000000    57.000000          6.000000
#
#        NumberOfPolicy  MonthlyIncome    Complaint  ExistingPolicyTenure  \
# count     4475.000000    4284.000000  4520.000000           4336.000000
# mean         3.565363   22890.309991     0.287168              4.130074
# ...

# %%
# From the above graph it can be concluded that there are some outliers in the SumAssured.

# %% [markdown]
# ## Correlation

# %% [markdown]
# Correlation coefficient measures linear relationship between a pair of variables, range [-1, 1]. 1 indicates full linear relationship, 0 no linear relationship, -1 negatively linear relationship.

# %%
# https://seaborn.pydata.org/generated/seaborn.heatmap.html
# to visualize the correlation between different columns in the dataset
import seaborn as sns
sns.set(rc={'figure.figsize':(12,10)})
corr_matrix = data.corr()
sns.heatmap(corr_matrix,annot=True)
plt.title("HeatMap Plot")
plt.xlabel("Column Names")
plt.ylabel("Column Names")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24568\1325693696.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = data.corr()

# %% [markdown]
# ## Histogram

# %%
a=data.AgentBonus.values
sns.distplot(a)

plt.title("Histogram Plot")
plt.xlabel("AgentBonus")
plt.ylabel("Frequency")
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24568\2193686403.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a)

# %%
data.dtypes
# Out:
# CustID                    int64
# AgentBonus                int64
# Age                     float64
# CustTenure              float64
# Channel                  object
# Occupation               object
# EducationField           object
# Gender                   object
# ExistingProdType          int64
# Designation              object
# NumberOfPolicy          float64
# MaritalStatus            object
# MonthlyIncome           float64
# Complaint                 int64
# ExistingPolicyTenure    float64
# SumAssured              float64
# Zone                     object
# PaymentMethod            object
# LastMonthCalls            int64
# CustCareScore           float64
# dtype: object

# %%
#Bivariate analysis of required columns and explanations
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the Excel file
df = pd.read_excel('Sales.xlsx', "Sales")
# print(df.columns)
# Select the required columns for analysis
columns_of_interest = ['AgentBonus', 'Age', 'CustTenure', 'MonthlyIncome', 'Complaint', 'CustCareScore']

# Descriptive statistics for each column
descriptive_stats = df[columns_of_interest].describe
print(descriptive_stats)

# Histograms for each column
df[columns_of_interest].hist(bins=10, figsize=(12, 8))
plt.tight_layout()
plt.show()

# Box plots for each column
df[columns_of_interest].boxplot(figsize=(12, 8))
plt.tight_layout()
plt.show()
# Out:
# <bound method NDFrame.describe of       AgentBonus   Age  CustTenure  MonthlyIncome  Complaint  CustCareScore
# 0           4409  22.0         4.0        20993.0          1            2.0
# 1           2214  11.0         2.0        20130.0          0            3.0
# 2           4273  26.0         4.0        17090.0          1            3.0
# 3           1791  11.0         NaN        17909.0          1            5.0
# 4           2955   6.0         NaN        18468.0          0            5.0
# ...          ...   ...         ...            ...        ...            ...
# 4515        3953   4.0         8.0        26355.0          0            1.0
# 4516        2939   9.0         9.0        20991.0          0            3.0
# 4517        3792  23.0        23.0            NaN          0            1.0
# 4518        4816  10.0        10.0        20068.0          0            5.0
# 4519        4764  14.0        10.0        23820.0          0            3.0
#
# [4520 rows x 6 columns]>

# %%
# There are some more outliers in the AgentBonus and Monthly income

# %%
# Multivariate analysis and observation

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the data from the Excel file
df = pd.read_excel('Sales.xlsx', "Sales")

# Select the required columns for analysis
columns_of_interest = ['AgentBonus', 'Age', 'CustTenure', 'MonthlyIncome', 'Complaint', 'CustCareScore']

# Compute correlation matrix
corr_matrix = df[columns_of_interest].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Outlier treatment of required
import pandas as pd
import numpy as np

# Load the data from the Excel file
df = pd.read_excel('Sales.xlsx', "Sales")
# Select the required columns for outlier treatment
columns_of_interest = ['AgentBonus', 'Age', 'CustTenure', 'MonthlyIncome', 'Complaint', 'CustCareScore']

# Define the outlier treatment function
def treat_outliers(column):
    q1 = np.percentile(column, 25)
    q3 = np.percentile(column, 75)
    iqr = q3 - q1
    lower_bound = q1 - 1.5 * iqr
    upper_bound = q3 + 1.5 * iqr
    column = np.where((column < lower_bound) | (column > upper_bound), np.median(column), column)
    return column

# Apply outlier treatment to the selected columns
for col in columns_of_interest:
    df[col] = treat_outliers(df[col])

# Verify the changes
print(df[columns_of_interest].describe())
# Out:
#         AgentBonus          Age   CustTenure  MonthlyIncome    Complaint  \
# count  4520.000000  4251.000000  4294.000000    4284.000000  4520.000000
# mean   3980.583628    14.494707    14.469027   22890.309991     0.287168
# std    1248.057571     9.037629     8.963671    4885.600757     0.452491
# min    1605.000000     2.000000     2.000000   16009.000000     0.000000
# 25%    3027.750000     7.000000     7.000000   19683.500000     0.000000
# 50%    3911.250000    13.000000    13.000000   21606.000000     0.000000
# 75%    4785.250000    20.000000    20.000000   24725.000000     1.000000
# max    7607.000000    58.000000    57.000000   38456.000000     1.000000
#
#        CustCareScore
# count    4468.000000
# mean        3.067592
# std         1.382968
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         5.000000

# %% [markdown]
# ## Encoding categorical features

# %% [markdown]
# Most machine learning methods take only numerical data, except decision tree based methods which can take numerical and categorical features directly. So we need to convert categories to numbers.

# %%
data.Channel.unique()
# Out:
# array(['Agent', 'Third Party Partner', 'Online'], dtype=object)

# %%
# data=pd.read_csv('CE802_P3_Data.csv')

def channel(s):
    if s=='Agent':
        return 1
    elif s=='Third Party Partner':
        return 2
    elif s=='Online':
        return 3

def occupation(s):
    if s=='Salaried':
        return 1
    elif s=='Free Lancer':
        return 2
    elif s=='Small Business':
        return 3
    elif s=='Laarge Business':
        return 4
    elif s=='Large Business':
        return 5

def education(s):
    if s=='Graduate':
        return 1
    elif s=='Post Graduate':
        return 2
    elif s=='UG':
        return 3
    elif s=='Under Graduate':
        return 4
    elif s=='Engineer':
        return 5
    elif s=='Diploma':
        return 6
    elif s=='MBA':
        return 7


def gender(s):
    if s=='Female' or s=='Fe male':
        return 1
    elif s=='Male':
        return 2

def designation(s):
    if s=='Manager':
        return 1
    elif s=='Exe':
        return 2
    elif s=='Executive':
        return 3
    elif s=='VP':
        return 4
    elif s=='AVP':
        return 5
    elif s=='Senior Manager':
        return 6


def maritalStatus(s):
    if s=='Single':
        return 1
    elif s=='Divorced':
        return 2
    elif s=='Unmarried':
        return 3
    elif s=='Married':
        return 4

def zone(s):
    if s=='North':
        return 1
    elif s=='West':
        return 2
    elif s=='East':
        return 3
    elif s=='South':
        return 4

def paymentMethod(s):
    if s=='Half Yearly':
        return 1
    elif s=='Yearly':
        return 2
    elif s=='Quarterly':
        return 3
    elif s=='Monthly':
        return 4

data['Channel']=data['Channel'].apply(channel)
data['Occupation']=data['Occupation'].apply(occupation)
data['EducationField']=data['EducationField'].apply(education)
data['Gender']=data['Gender'].apply(gender)

data['Designation']=data['Designation'].apply(designation)
data['MaritalStatus']=data['MaritalStatus'].apply(maritalStatus)
data['Zone']=data['Zone'].apply(zone)

data['PaymentMethod']=data['PaymentMethod'].apply(paymentMethod)

# %%
data
# Out:
#        CustID  AgentBonus   Age  CustTenure  Channel  Occupation  \
# 0     7000000        4409  22.0         4.0        1           1
# 1     7000001        2214  11.0         2.0        2           1
# 2     7000002        4273  26.0         4.0        1           2
# 3     7000003        1791  11.0         NaN        2           1
# 4     7000004        2955   6.0         NaN        1           3
# ...       ...         ...   ...         ...      ...         ...
# 4515  7004515        3953   4.0         8.0        1           3
# 4516  7004516        2939   9.0         9.0        1           1
# 4517  7004517        3792  23.0        23.0        1           1
# 4518  7004518        4816  10.0        10.0        3           3
# 4519  7004519        4764  14.0        10.0        1           1
#
#       EducationField  Gender  ExistingProdType  Designation  NumberOfPolicy  \
# 0                  1       1                 3            1             2.0
# ...

# %%
data.dtypes
# Out:
# CustID                    int64
# AgentBonus                int64
# Age                     float64
# CustTenure              float64
# Channel                   int64
# Occupation                int64
# EducationField            int64
# Gender                    int64
# ExistingProdType          int64
# Designation               int64
# NumberOfPolicy          float64
# MaritalStatus             int64
# MonthlyIncome           float64
# Complaint                 int64
# ExistingPolicyTenure    float64
# SumAssured              float64
# Zone                      int64
# PaymentMethod             int64
# LastMonthCalls            int64
# CustCareScore           float64
# dtype: object

# %% [markdown]
# # Data Preprocessing
#
# ## Dealing with missing values

# %% [markdown]
# We first check if there are missing values in each feature, 0 for no missing value or the number for the number of missing values.

# %%
data.isna().sum()
# Out:
# CustID                    0
# AgentBonus                0
# Age                     269
# CustTenure              226
# Channel                   0
# Occupation                0
# EducationField            0
# Gender                    0
# ExistingProdType          0
# Designation               0
# NumberOfPolicy           45
# MaritalStatus             0
# MonthlyIncome           236
# Complaint                 0
# ExistingPolicyTenure    184
# SumAssured              154
# Zone                      0
# PaymentMethod             0
# LastMonthCalls            0
# CustCareScore            52
# dtype: int64

# %% [markdown]
# As you can see from above, there are some missing values in this data so need to perform any action over data.

# %%
data.dropna(inplace=True)

# %%
data.dtypes
# Out:
# CustID                    int64
# AgentBonus                int64
# Age                     float64
# CustTenure              float64
# Channel                   int64
# Occupation                int64
# EducationField            int64
# Gender                    int64
# ExistingProdType          int64
# Designation               int64
# NumberOfPolicy          float64
# MaritalStatus             int64
# MonthlyIncome           float64
# Complaint                 int64
# ExistingPolicyTenure    float64
# SumAssured              float64
# Zone                      int64
# PaymentMethod             int64
# LastMonthCalls            int64
# CustCareScore           float64
# dtype: object

# %%
Input_data=data[['CustID',  'Age', 'CustTenure', 'Channel', 'Occupation',
       'EducationField', 'Gender', 'ExistingProdType', 'Designation',
       'NumberOfPolicy', 'MaritalStatus', 'MonthlyIncome', 'Complaint',
       'ExistingPolicyTenure', 'SumAssured', 'Zone', 'PaymentMethod',
       'LastMonthCalls', 'CustCareScore']]
Target=data[['AgentBonus']]

# %% [markdown]
# ## Model Implementation

# %%
# Train Test Split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(Input_data, Target, test_size=0.33, random_state=42)

# %%
# Linear Regression
from sklearn.linear_model import LinearRegression
clf1 = LinearRegression()
clf1.fit(X_train,y_train)
pred=clf1.predict(X_test)
linearRegressionScore=clf1.score(X_test,y_test)
print("LinearRegression Testing accuracy: ",linearRegressionScore)
# Out:
# LinearRegression Testing accuracy:  0.7862454613477956

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, pred)
plt.xlabel('Actual Values (y_test)')
plt.ylabel('Predicted Values (pred)')
plt.title('Linear Regression: Actual vs. Predicted')
plt.show()

# %%
# performance metrics
from sklearn.metrics import mean_squared_error
errors1=mean_squared_error(y_test,pred)
print('root mean_squared_error = ',errors1)

from sklearn.metrics import mean_absolute_error
error2=mean_absolute_error(y_test,pred)
print('mean_absolute_error = ',error2)

errors3=mean_squared_error(y_test,pred)
print('mean_squared_error = ',errors3)
# Out:
# root mean_squared_error =  360745.7026181395
# mean_absolute_error =  481.15727785230337
# mean_squared_error =  360745.7026181395

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
clf2 = DecisionTreeRegressor()
clf2.fit(X_train,y_train)
pred=clf2.predict(X_test)
DecisionTreeRegressorScore=clf2.score(X_test,y_test)
print("DecisionTreeRegressor Testing accuracy: ",DecisionTreeRegressorScore)
# Out:
# DecisionTreeRegressor Testing accuracy:  0.6806653288979334

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, pred)
plt.xlabel('Actual Values (y_test)')
plt.ylabel('Predicted Values (pred)')
plt.title('Linear Regression: Actual vs. Predicted')
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
from sklearn.metrics import mean_squared_error
errors1=mean_squared_error(y_test,pred)
print('root mean_squared_error = ',errors1)

from sklearn.metrics import mean_absolute_error
error2=mean_absolute_error(y_test,pred)
print('mean_absolute_error = ',error2)

errors3=mean_squared_error(y_test,pred)
print('mean_squared_error = ',errors3)
# Out:
# root mean_squared_error =  538929.4235500878
# mean_absolute_error =  536.6133567662566
# mean_squared_error =  538929.4235500878

# %% [markdown]
# ### RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
clf3 = RandomForestRegressor()
clf3.fit(X_train,y_train)
pred=clf3.predict(X_test)
randomForestScore=clf3.score(X_test,y_test)
print("RandomForestRegressor Testing accuracy: ",randomForestScore)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_24568\414283647.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf3.fit(X_train,y_train)
# RandomForestRegressor Testing accuracy:  0.8433281098774055

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, pred)
plt.xlabel('Actual Values (y_test)')
plt.ylabel('Predicted Values (pred)')
plt.title('Linear Regression: Actual vs. Predicted')
plt.show()

# %% [markdown]
# ### Performance Metrics

# %%
from sklearn.metrics import mean_squared_error
errors1=mean_squared_error(y_test,pred)
print('root mean_squared_error = ',errors1)

from sklearn.metrics import mean_absolute_error
error2=mean_absolute_error(y_test,pred)
print('mean_absolute_error = ',error2)

errors3=mean_squared_error(y_test,pred)
print('mean_squared_error = ',errors3)
# Out:
# root mean_squared_error =  264409.4082827768
# mean_absolute_error =  396.54052724077326
# mean_squared_error =  264409.4082827768

# %% [markdown]
# ### Interpretation of the model(s)

# %%
import matplotlib.pyplot as plt
a=["Linear Regression","Decision Tree","Random Forest"]
b=[linearRegressionScore,DecisionTreeRegressorScore,randomForestScore]
plt.bar(a,b,color="green",width=0.2)
plt.yscale("log")
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Graph Model for Accuracy of all models")
plt.show()

# %% [markdown]
# We can conclude that random forest works best over the sales dataset.
